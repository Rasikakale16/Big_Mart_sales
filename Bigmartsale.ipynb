# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv("../DataSets/Bigmartsales.csv")

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# 1                  Dairy   87.3198            OUT017
# 2                 Others  241.7538            OUT010
# 3            Snack Foods  155.0340            OUT017
# 4                  Dairy  234.2300            OUT027
# ...                  ...       ...               ...
# 5676         Snack Foods  141.3154            OUT046
# 5677       Starchy Foods  169.1448            OUT018
# 5678  Health and Hygiene  118.7440            OUT045
# 5679              Canned  214.6218            OUT017
# 5680              Canned   79.7960            OUT045
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2007         NaN               Tier 2
# 2                          1998         NaN               Tier 3
# 3                          2007         NaN               Tier 2
# 4                          1985      Medium               Tier 3
# ...                         ...         ...                  ...
# 5676                       1997       Small               Tier 1
# 5677                       2009      Medium               Tier 3
# 5678                       2002         NaN               Tier 2
# 5679                       2007         NaN               Tier 2
# 5680                       2002         NaN               Tier 2
#
#             Outlet_Type
# 0     Supermarket Type1
# 1     Supermarket Type1
# 2         Grocery Store
# 3     Supermarket Type1
# 4     Supermarket Type3
# ...                 ...
# 5676  Supermarket Type1
# 5677  Supermarket Type2
# 5678  Supermarket Type1
# 5679  Supermarket Type1
# 5680  Supermarket Type1
#
# [5681 rows x 11 columns]

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# 0               Tier 1  Supermarket Type1
# 1               Tier 2  Supermarket Type1
# 2               Tier 3      Grocery Store
# 3               Tier 2  Supermarket Type1
# 4               Tier 3  Supermarket Type3

# %%
df.Item_Fat_Content.unique()
# Out:
# array(['Low Fat', 'reg', 'Regular', 'LF', 'low fat'], dtype=object)

# %%
df.Outlet_Identifier.unique()
# Out:
# array(['OUT049', 'OUT017', 'OUT010', 'OUT027', 'OUT046', 'OUT018',
#        'OUT045', 'OUT019', 'OUT013', 'OUT035'], dtype=object)

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# dtype: object

# %%
df.count()
# Out:
# Item_Identifier              5681
# Item_Weight                  4705
# Item_Fat_Content             5681
# Item_Visibility              5681
# Item_Type                    5681
# Item_MRP                     5681
# Outlet_Identifier            5681
# Outlet_Establishment_Year    5681
# Outlet_Size                  4075
# Outlet_Location_Type         5681
# Outlet_Type                  5681
# dtype: int64

# %%
df.Outlet_Identifier.count()
# Out:
# 5681

# %%
df.Outlet_Identifier.value_counts()
# Out:
# OUT027    624
# OUT013    621
# OUT049    620
# OUT046    620
# OUT035    620
# OUT045    619
# OUT018    618
# OUT017    617
# OUT010    370
# OUT019    352
# Name: Outlet_Identifier, dtype: int64

# %%
pd.crosstab(index =[df.Outlet_Identifier,df.Outlet_Location_Type],columns = df.Outlet_Size)
# Out:
# Outlet_Size                             High  Medium  Small
# Outlet_Identifier Outlet_Location_Type
# OUT013            Tier 3                 621       0      0
# OUT018            Tier 3                   0     618      0
# OUT019            Tier 1                   0       0    352
# OUT027            Tier 3                   0     624      0
# OUT035            Tier 2                   0       0    620
# OUT046            Tier 1                   0       0    620
# OUT049            Tier 1                   0     620      0

# %%
pd.crosstab(index= [df.Outlet_Establishment_Year,df.Item_Fat_Content], columns = df.Item_Type, margins = True, margins_name = 'Total')
# Out:
# Item_Type                                   Baking Goods  Breads  Breakfast  \
# Outlet_Establishment_Year Item_Fat_Content
# 1985                      LF                           0       5          0
#                           Low Fat                     29       8          5
#                           Regular                     43      13          8
#                           low fat                      0       0          0
#                           reg                          2       0          0
# 1987                      LF                           2       0          0
#                           Low Fat                     22       7          1
#                           Regular                     19      11          6
#                           low fat                      0       1          0
#                           reg                          3       1          0
# 1997                      LF                           1       2          0
#                           Low Fat                     20       9          4
#                           Regular                     20       7          6
#                           low fat                      0       0          0
#                           reg                          2       0          0
# 1998                      LF                           0       0          1
#                           Low Fat                     15       7          0
#                           Regular                     14       6          2
#                           low fat                      1       0          0
#                           reg                          0       0          0
# 1999                      LF                           1       0          0
#                           Low Fat                     28      11          3
#                           Regular                     23       9          4
#                           low fat                      1       0          0
#                           reg                          0       0          0
# 2002                      LF                           0       0          0
#                           Low Fat                     20       6          2
#                           Regular                     25       6          8
#                           low fat                      1       0          0
#                           reg                          1       0          0
# 2004                      LF                           1       2          0
#                           Low Fat                     22       6          4
#                           Regular                     27       8          6
#                           low fat                      0       0          0
#                           reg                          0       0          0
# 2007                      LF                           2       0          0
#                           Low Fat                     22      10          2
#                           Regular                     20      12          6
#                           low fat                      0       0          0
#                           reg                          0       0          0
# 2009                      LF                           0       0          0
#                           Low Fat                     25       8          3
#                           Regular                     25       9          5
#                           low fat                      0       0          0
#                           reg                          1       1          0
# Total                                                438     165         76
#
# Item_Type                                   Canned  Dairy  Frozen Foods  \
# Outlet_Establishment_Year Item_Fat_Content
# 1985                      LF                     3      5             4
#                           Low Fat               37     50            47
#                           Regular               34     23            60
#                           low fat                0      0             1
#                           reg                    2      1             1
# 1987                      LF                     0      2             1
#                           Low Fat               24     21            29
#                           Regular               26     20            30
#                           low fat                2      0             2
#                           reg                    1      1             1
# 1997                      LF                     3      0             3
#                           Low Fat               20     27            20
#                           Regular               21     18            22
#                           low fat                2      0             0
#                           reg                    2      1             1
# 1998                      LF                     0      1             1
#                           Low Fat               17     12            17
#                           Regular               13     15            21
#                           low fat                0      0             0
#                           reg                    1      0             0
# 1999                      LF                     1      1             1
#                           Low Fat               19     25            27
#                           Regular               27     20            32
#                           low fat                0      0             1
#                           reg                    5      0             1
# 2002                      LF                     4      3             1
#                           Low Fat               19     28            31
#                           Regular               22     22            40
#                           low fat                0      2             0
#                           reg                    1      1             1
# 2004                      LF                     0      2             3
#                           Low Fat               16     32            34
#                           Regular               20     18            24
#                           low fat                1      0             0
#                           reg                    2      1             2
# 2007                      LF                     1      1             3
#                           Low Fat               19     28            21
#                           Regular               27     19            23
#                           low fat                0      0             1
#                           reg                    2      3             1
# 2009                      LF                     1      0             2
#                           Low Fat               18     31            31
#                           Regular               20     18            29
#                           low fat                1      2             0
#                           reg                    1      0             0
# Total                                          435    454           570
#
# Item_Type                                   Fruits and Vegetables  \
# Outlet_Establishment_Year Item_Fat_Content
# 1985                      LF                                    4
#                           Low Fat                              66
#                           Regular                              58
#                           low fat                               3
#                           reg                                   2
# 1987                      LF                                    4
#                           Low Fat                              42
#                           Regular                              31
#                           low fat                               0
#                           reg                                   1
# 1997                      LF                                    2
#                           Low Fat                              51
#                           Regular                              39
#                           low fat                               1
#                           reg                                   1
# 1998                      LF                                    5
#                           Low Fat                              34
#                           Regular                              18
#                           low fat                               1
#                           reg                                   0
# 1999                      LF                                    2
#                           Low Fat                              49
#                           Regular                              29
#                           low fat                               0
#                           reg                                   1
# 2002                      LF                                    1
#                           Low Fat                              40
#                           Regular                              32
#                           low fat                               0
#                           reg                                   2
# 2004                      LF                                    4
#                           Low Fat                              46
#                           Regular                              39
#                           low fat                               1
#                           reg                                   0
# 2007                      LF                                    2
#                           Low Fat                              49
#                           Regular                              35
#                           low fat                               2
#                           reg                                   0
# 2009                      LF                                    3
#                           Low Fat                              44
#                           Regular                              37
#                           low fat                               0
#                           reg                                   0
# Total                                                         781
#
# Item_Type                                   Hard Drinks  Health and Hygiene  \
# Outlet_Establishment_Year Item_Fat_Content
# 1985                      LF                          0                   2
#                           Low Fat                    27                  55
#                           Regular                     0                   0
#                           low fat                     1                   1
#                           reg                         0                   0
# 1987                      LF                          2                   2
#                           Low Fat                    15                  31
#                           Regular                     0                   0
#                           low fat                     0                   0
#                           reg                         0                   0
# 1997                      LF                          1                   4
#                           Low Fat                    18                  33
#                           Regular                     0                   0
#                           low fat                     0                   2
#                           reg                         0                   0
# 1998                      LF                          0                   3
#                           Low Fat                     9                  15
#                           Regular                     0                   0
#                           low fat                     0                   0
#                           reg                         0                   0
# 1999                      LF                          0                   4
#                           Low Fat                    10                  39
#                           Regular                     0                   0
#                           low fat                     0                   0
#                           reg                         0                   0
# 2002                      LF                          0                   1
#                           Low Fat                    11                  37
#                           Regular                     0                   0
#                           low fat                     1                   1
#                           reg                         0                   0
# 2004                      LF                          0                   2
#                           Low Fat                    17                  40
#                           Regular                     0                   0
#                           low fat                     1                   1
#                           reg                         0                   0
# 2007                      LF                          1                   1
#                           Low Fat                    16                  30
#                           Regular                     0                   0
#                           low fat                     1                   0
#                           reg                         0                   0
# 2009                      LF                          0                   1
#                           Low Fat                    16                  33
#                           Regular                     0                   0
#                           low fat                     1                   0
#                           reg                         0                   0
# Total                                               148                 338
#
# Item_Type                                   Household  Meat  Others  Seafood  \
# Outlet_Establishment_Year Item_Fat_Content
# 1985                      LF                        6     1       1        0
#                           Low Fat                 101    10      19        1
#                           Regular                   0    27       0        2
#                           low fat                   5     0       0        0
#                           reg                       0     3       0        0
# 1987                      LF                        2     1       1        0
#                           Low Fat                  63    15      13        2
#                           Regular                   0    23       0        3
#                           low fat                   0     0       0        0
#                           reg                       0     0       0        0
# 1997                      LF                        4     2       0        0
#                           Low Fat                  59    11       8        4
#                           Regular                   0    22       0        0
#                           low fat                   3     0       0        0
#                           reg                       0     1       0        0
# 1998                      LF                        2     0       2        0
#                           Low Fat                  35     3       6        0
#                           Regular                   0    13       0        0
#                           low fat                   0     1       0        0
#                           reg                       0     1       0        0
# 1999                      LF                        2     0       3        0
#                           Low Fat                  71    13      10        2
#                           Regular                   0    17       0        1
#                           low fat                   0     0       0        0
#                           reg                       0     1       0        0
# 2002                      LF                        6     1       0        0
#                           Low Fat                  65    17      10        1
#                           Regular                   0    22       0        0
#                           low fat                   0     1       0        0
#                           reg                       0     0       0        0
# 2004                      LF                        5     1       0        0
#                           Low Fat                  62    12      13        0
#                           Regular                   0    24       0        2
#                           low fat                   0     0       1        0
#                           reg                       0     0       0        0
# 2007                      LF                        5     0       0        0
#                           Low Fat                  67    15      14        3
#                           Regular                   0    20       0        1
#                           low fat                   2     0       0        0
#                           reg                       0     1       0        0
# 2009                      LF                        2     0       0        0
#                           Low Fat                  71     8      10        3
#                           Regular                   0    23       0        0
#                           low fat                   0     0       0        0
#                           reg                       0     1       0        0
# Total                                             638   311     111       25
#
# Item_Type                                   Snack Foods  Soft Drinks  \
# Outlet_Establishment_Year Item_Fat_Content
# 1985                      LF                          3            2
#                           Low Fat                    61           43
#                           Regular                    54            6
#                           low fat                     5            1
#                           reg                         1            0
# 1987                      LF                          5            1
#                           Low Fat                    53           26
#                           Regular                    34            2
#                           low fat                     0            1
#                           reg                         3            1
# 1997                      LF                          5            0
#                           Low Fat                    51           23
#                           Regular                    37            7
#                           low fat                     1            2
#                           reg                         2            0
# 1998                      LF                          2            1
#                           Low Fat                    26           15
#                           Regular                    22            2
#                           low fat                     0            0
#                           reg                         2            0
# 1999                      LF                          1            4
#                           Low Fat                    42           25
#                           Regular                    34            3
#                           low fat                     1            1
#                           reg                         2            0
# 2002                      LF                          3            3
#                           Low Fat                    47           17
#                           Regular                    34            6
#                           low fat                     1            0
#                           reg                         0            1
# 2004                      LF                          3            1
#                           Low Fat                    33           23
#                           Regular                    41            2
#                           low fat                     0            1
#                           reg                         2            1
# 2007                      LF                          4            0
#                           Low Fat                    51           26
#                           Regular                    35            0
#                           low fat                     0            0
#                           reg                         1            0
# 2009                      LF                          1            2
#                           Low Fat                    49           25
#                           Regular                    34            7
#                           low fat                     1            0
#                           reg                         2            0
# Total                                               789          281
#
# Item_Type                                   Starchy Foods  Total
# Outlet_Establishment_Year Item_Fat_Content
# 1985                      LF                            1     37
#                           Low Fat                      14    573
#                           Regular                       8    336
#                           low fat                       0     17
#                           reg                           1     13
# 1987                      LF                            0     23
#                           Low Fat                       5    369
#                           Regular                       6    211
#                           low fat                       0      6
#                           reg                           0     12
# 1997                      LF                            0     27
#                           Low Fat                      10    368
#                           Regular                       5    204
#                           low fat                       0     11
#                           reg                           0     10
# 1998                      LF                            0     18
#                           Low Fat                       4    215
#                           Regular                       4    130
#                           low fat                       0      3
#                           reg                           0      4
# 1999                      LF                            0     20
#                           Low Fat                       9    383
#                           Regular                       4    203
#                           low fat                       0      4
#                           reg                           0     10
# 2002                      LF                            0     23
#                           Low Fat                      11    362
#                           Regular                       3    220
#                           low fat                       0      7
#                           reg                           0      7
# 2004                      LF                            1     25
#                           Low Fat                       5    365
#                           Regular                       5    216
#                           low fat                       0      6
#                           reg                           0      8
# 2007                      LF                            0     20
#                           Low Fat                       5    378
#                           Regular                       6    204
#                           low fat                       1      7
#                           reg                           0      8
# 2009                      LF                            1     13
#                           Low Fat                       8    383
#                           Regular                       4    211
#                           low fat                       0      5
#                           reg                           0      6
# Total                                                 121   5681

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5681, step=1)

# %%
df.isnull()
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0               False        False             False            False
# 1               False        False             False            False
# 2               False        False             False            False
# 3               False        False             False            False
# 4               False         True             False            False
# ...               ...          ...               ...              ...
# 5676            False        False             False            False
# 5677            False        False             False            False
# 5678            False        False             False            False
# 5679            False        False             False            False
# 5680            False        False             False            False
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# 0         False     False              False                      False
# 1         False     False              False                      False
# 2         False     False              False                      False
# 3         False     False              False                      False
# 4         False     False              False                      False
# ...         ...       ...                ...                        ...
# 5676      False     False              False                      False
# 5677      False     False              False                      False
# 5678      False     False              False                      False
# 5679      False     False              False                      False
# 5680      False     False              False                      False
#
#       Outlet_Size  Outlet_Location_Type  Outlet_Type
# 0           False                 False        False
# 1            True                 False        False
# 2            True                 False        False
# 3            True                 False        False
# 4           False                 False        False
# ...           ...                   ...          ...
# 5676        False                 False        False
# 5677        False                 False        False
# 5678         True                 False        False
# 5679         True                 False        False
# 5680         True                 False        False
#
# [5681 rows x 11 columns]

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
df.Item_Weight.mean()
# Out:
# 12.695633368756374

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# 1                  Dairy   87.3198            OUT017
# 2                 Others  241.7538            OUT010
# 3            Snack Foods  155.0340            OUT017
# 4                  Dairy  234.2300            OUT027
# ...                  ...       ...               ...
# 5676         Snack Foods  141.3154            OUT046
# 5677       Starchy Foods  169.1448            OUT018
# 5678  Health and Hygiene  118.7440            OUT045
# 5679              Canned  214.6218            OUT017
# 5680              Canned   79.7960            OUT045
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2007         NaN               Tier 2
# 2                          1998         NaN               Tier 3
# 3                          2007         NaN               Tier 2
# 4                          1985      Medium               Tier 3
# ...                         ...         ...                  ...
# 5676                       1997       Small               Tier 1
# 5677                       2009      Medium               Tier 3
# 5678                       2002         NaN               Tier 2
# 5679                       2007         NaN               Tier 2
# 5680                       2002         NaN               Tier 2
#
#             Outlet_Type
# 0     Supermarket Type1
# 1     Supermarket Type1
# 2         Grocery Store
# 3     Supermarket Type1
# 4     Supermarket Type3
# ...                 ...
# 5676  Supermarket Type1
# 5677  Supermarket Type2
# 5678  Supermarket Type1
# 5679  Supermarket Type1
# 5680  Supermarket Type1
#
# [5681 rows x 11 columns]

# %%
df.Item_Weight = df.Item_Weight.fillna('12.69')
df
# Out:
#      Item_Identifier Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.75          Low Fat         0.007565
# 1              FDW14         8.3              reg         0.038428
# 2              NCN55        14.6          Low Fat         0.099575
# 3              FDQ58       7.315          Low Fat         0.015388
# 4              FDY38       12.69          Regular         0.118599
# ...              ...         ...              ...              ...
# 5676           FDB58        10.5          Regular         0.013496
# 5677           FDD47         7.6          Regular         0.142991
# 5678           NCO17        10.0          Low Fat         0.073529
# 5679           FDJ26        15.3          Regular         0.000000
# 5680           FDU37         9.5          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# 1                  Dairy   87.3198            OUT017
# 2                 Others  241.7538            OUT010
# 3            Snack Foods  155.0340            OUT017
# 4                  Dairy  234.2300            OUT027
# ...                  ...       ...               ...
# 5676         Snack Foods  141.3154            OUT046
# 5677       Starchy Foods  169.1448            OUT018
# 5678  Health and Hygiene  118.7440            OUT045
# 5679              Canned  214.6218            OUT017
# 5680              Canned   79.7960            OUT045
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2007         NaN               Tier 2
# 2                          1998         NaN               Tier 3
# 3                          2007         NaN               Tier 2
# 4                          1985      Medium               Tier 3
# ...                         ...         ...                  ...
# 5676                       1997       Small               Tier 1
# 5677                       2009      Medium               Tier 3
# 5678                       2002         NaN               Tier 2
# 5679                       2007         NaN               Tier 2
# 5680                       2002         NaN               Tier 2
#
#             Outlet_Type
# 0     Supermarket Type1
# 1     Supermarket Type1
# 2         Grocery Store
# 3     Supermarket Type1
# 4     Supermarket Type3
# ...                 ...
# 5676  Supermarket Type1
# 5677  Supermarket Type2
# 5678  Supermarket Type1
# 5679  Supermarket Type1
# 5680  Supermarket Type1
#
# [5681 rows x 11 columns]

# %%
df.Outlet_Size.mode()  #string object ka mode nikalenge.
# Out:
# 0    Medium
# Name: Outlet_Size, dtype: object

# %%
df.Outlet_Size = df.Outlet_Size.fillna('Medium')
df
# Out:
#      Item_Identifier Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.75          Low Fat         0.007565
# 1              FDW14         8.3              reg         0.038428
# 2              NCN55        14.6          Low Fat         0.099575
# 3              FDQ58       7.315          Low Fat         0.015388
# 4              FDY38       12.69          Regular         0.118599
# ...              ...         ...              ...              ...
# 5676           FDB58        10.5          Regular         0.013496
# 5677           FDD47         7.6          Regular         0.142991
# 5678           NCO17        10.0          Low Fat         0.073529
# 5679           FDJ26        15.3          Regular         0.000000
# 5680           FDU37         9.5          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# 1                  Dairy   87.3198            OUT017
# 2                 Others  241.7538            OUT010
# 3            Snack Foods  155.0340            OUT017
# 4                  Dairy  234.2300            OUT027
# ...                  ...       ...               ...
# 5676         Snack Foods  141.3154            OUT046
# 5677       Starchy Foods  169.1448            OUT018
# 5678  Health and Hygiene  118.7440            OUT045
# 5679              Canned  214.6218            OUT017
# 5680              Canned   79.7960            OUT045
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2007      Medium               Tier 2
# 2                          1998      Medium               Tier 3
# 3                          2007      Medium               Tier 2
# 4                          1985      Medium               Tier 3
# ...                         ...         ...                  ...
# 5676                       1997       Small               Tier 1
# 5677                       2009      Medium               Tier 3
# 5678                       2002      Medium               Tier 2
# 5679                       2007      Medium               Tier 2
# 5680                       2002      Medium               Tier 2
#
#             Outlet_Type
# 0     Supermarket Type1
# 1     Supermarket Type1
# 2         Grocery Store
# 3     Supermarket Type1
# 4     Supermarket Type3
# ...                 ...
# 5676  Supermarket Type1
# 5677  Supermarket Type2
# 5678  Supermarket Type1
# 5679  Supermarket Type1
# 5680  Supermarket Type1
#
# [5681 rows x 11 columns]

# %%
print(df.Item_Identifier.unique())
Item = input("Enter Item identifier code:")
a = df[df.Item_Identifier == Item]
print(df.Item_Type.unique())
Type = input("Enter Item Type:")
b = df[df.Item_Type == Type]
b
# Out:
# ['FDW58' 'FDW14' 'NCN55' ... 'NCI29' 'FDP28' 'FDF04']
# Enter Item identifier code:jdgqwjad
# ['Snack Foods' 'Dairy' 'Others' 'Fruits and Vegetables' 'Baking Goods'
#  'Health and Hygiene' 'Breads' 'Hard Drinks' 'Seafood' 'Soft Drinks'
#  'Household' 'Frozen Foods' 'Meat' 'Canned' 'Starchy Foods' 'Breakfast']
# Enter Item Type: fjsbjf
# Empty DataFrame
# Columns: [Item_Identifier, Item_Weight, Item_Fat_Content, Item_Visibility, Item_Type, Item_MRP, Outlet_Identifier, Outlet_Establishment_Year, Outlet_Size, Outlet_Location_Type, Outlet_Type]
# Index: []

# %%
#HIDDEN PARAMETERS
print(df.Item_Fat_Content.unique())
Item = input("Enter Item identifier code:")
a = df[df.Item_Identifier == Item]
print(df.Item_Type.unique())
Type = input("Enter Item Type:")
b = df[df.Item_Type == Type]
b

w = plt.figure(figsize =[15,7])
w.add_subplot(121)
ax1=sb.barplot(b.Outlet_Identifier,b.Item_MRP,palette='hot')
plt.xticks(rotation = 90)
plt.title("%s_models" %(Item))
# Out:
# ['Low Fat' 'reg' 'Regular' 'LF' 'low fat']
# Enter Item identifier code:LF
# ['Snack Foods' 'Dairy' 'Others' 'Fruits and Vegetables' 'Baking Goods'
#  'Health and Hygiene' 'Breads' 'Hard Drinks' 'Seafood' 'Soft Drinks'
#  'Household' 'Frozen Foods' 'Meat' 'Canned' 'Starchy Foods' 'Breakfast']
# Enter Item Type:Meat
# C:\Users\rasik\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\temps\ipykernel_16916\787875970.py in <module>
#      12 ax1=sb.barplot(b.Outlet_Identifier,b.Item_MRP,palette='hot')
#      13 plt.xticks(rotation = 90)
# ---> 14 plt.title("%LF_models" %(Item))
#
# TypeError: must be real number, not str

# %%
#VISUALS

# %%
sb.lmplot(x='Item_Weight',y='Item_MRP',col='',data=df,fit_reg=False)
plt.show()

# %%
df.Item_Fat_Content.value_counts()
# Out:
# Low Fat    3396
# Regular    1935
# LF          206
# reg          78
# low fat      66
# Name: Item_Fat_Content, dtype: int64

# %%
sb.kdeplot(data = df.Outlet_Establishment_Year)
plt.show()

# %%
sb.boxplot(df.Outlet_Establishment_Year)
plt.show()
# Out:
# C:\Users\rasik\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sb.violinplot(df.Outlet_Establishment_Year,palette = 'summer')
plt.show()
# Out:
# C:\Users\rasik\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sb.stripplot(df.Outlet_Establishment_Year,df.Item_MRP)
plt.show()
# Out:
# C:\Users\rasik\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sb.swarmplot(df.Item_MRP)
plt.show()
# Out:
# C:\Users\rasik\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\rasik\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 52.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sb.jointplot(df.Item_MRP,df.Item_Weight,color='k')
plt.show()

# %%
#STATS 
df = [df.Item_Identifier== 'Dairy']

# %%
df.Outlet_Identifier.min()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\temps\ipykernel_16916\461810681.py in <module>
# ----> 1 df.Outlet_Identifier.min()
#
# AttributeError: 'list' object has no attribute 'Outlet_Identifier'

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year
# count  4705.000000      5681.000000  5681.000000                5681.000000
# mean     12.695633         0.065684   141.023273                1997.828903
# std       4.664849         0.051252    61.809091                   8.372256
# min       4.555000         0.000000    31.990000                1985.000000
# 25%       8.645000         0.027047    94.412000                1987.000000
# 50%      12.500000         0.054154   141.415400                1999.000000
# 75%      16.700000         0.093463   186.026600                2004.000000
# max      21.350000         0.323637   266.588400                2009.000000

# %%
df.covariance()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\temps\ipykernel_16916\2855166570.py in <module>
# ----> 1 df.covariance()
#
# AttributeError: 'list' object has no attribute 'covariance'

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\temps\ipykernel_16916\1134722465.py in <module>
# ----> 1 df.corr()
#
# AttributeError: 'list' object has no attribute 'corr'

# %%
df.std()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\temps\ipykernel_16916\3390915376.py in <module>
# ----> 1 df.std()
#
# AttributeError: 'list' object has no attribute 'std'
